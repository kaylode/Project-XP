# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data
from torch.autograd import Variable
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from torchvision import datasets, transforms, models
from torchsummary import summary

# %%
device = torch.device("cuda: 0" if torch.cuda.is_available() else "cpu")

# %%
IMG_SIZE = 32

# %%
DATA_DIR = {
    "train": "data"
}

# %%
train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(IMG_SIZE, padding = 2),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

val_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
trainset = datasets.CIFAR10(DATA_DIR["train"],
                            train= True,
                            transform=train_transform,
                            download = True)
testset = datasets.CIFAR10(DATA_DIR["train"],
                            train= False,
                            transform=val_transform,
                            download = True)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
CLASSES = trainset.classes
NUM_CLASSES = len(CLASSES)

# %%
print(f"Number of training samples: {len(trainset)}")
print(f"Number of vaidating samples: {len(testset)}")
print(f"Number of unique labels : {NUM_CLASSES}")
print(f"Unique labels name: \n{CLASSES}")
# Out:
# Number of training samples: 50000
# Number of vaidating samples: 10000
# Number of unique labels : 10
# Unique labels name:
# ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# Visualize some training samples
from mpl_toolkits.axes_grid1 import ImageGrid

def visualize_samples(NUM_PIC=10):
    a = np.random.randint(100-NUM_PIC)
    fig = plt.figure(figsize=(NUM_PIC*2,NUM_PIC*2))
    plt.title("Training Samples", fontsize=25)
    plt.xticks([])
    plt.yticks(np.arange(10)[-1:-11:-1]+0.3, CLASSES, fontsize=25)
    grid = ImageGrid(fig, 111, (NUM_PIC,NUM_PIC), axes_pad=0)
    
    imgs_id_list = []
    for i in range(10):
        imgs_id = np.where(np.array(trainset.targets) == i)
        imgs_id_list += list(imgs_id[0][a:a+NUM_PIC])
    
    
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    
    for ax, im_id in zip(grid, imgs_id_list):
        img = trainset[im_id][0]
        img = img.numpy().transpose((1,2,0))
        img = (img*std + mean)
        img = np.clip(img,0,1)
        ax.imshow(img)
        ax.axis("off")
    
    
    plt.show()
    
    
visualize_samples()

# %%
def visualize_frequency():
    id_count = {CLASSES[i]: len(np.where(np.array(trainset.targets) == i)[0]) for i in range(10)}

    fig = plt.subplots(figsize=(15,10))
    plt.bar(id_count.keys(), height=id_count.values())
    plt.title("Frequency of each class", fontsize= 20)
    plt.xlabel("Class", fontsize= 20)
    plt.ylabel("Number of samples", fontsize= 20)
    plt.show()
    
visualize_frequency()

# %%
# Load pretrained model

model = models.resnet18(pretrained=True)
for params in model.parameters():
    params.requires_grad = False
model.fc = nn.Linear(512,10)
model = model.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=2e-4, weight_decay = 1e-5, betas=(0.5, 0.999))
criterion = nn.CrossEntropyLoss()

summary(model, (3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 16, 16]           9,408
#        BatchNorm2d-2           [-1, 64, 16, 16]             128
#               ReLU-3           [-1, 64, 16, 16]               0
#          MaxPool2d-4             [-1, 64, 8, 8]               0
#             Conv2d-5             [-1, 64, 8, 8]          36,864
#        BatchNorm2d-6             [-1, 64, 8, 8]             128
#               ReLU-7             [-1, 64, 8, 8]               0
#             Conv2d-8             [-1, 64, 8, 8]          36,864
#        BatchNorm2d-9             [-1, 64, 8, 8]             128
#              ReLU-10             [-1, 64, 8, 8]               0
#        BasicBlock-11             [-1, 64, 8, 8]               0
#            Conv2d-12             [-1, 64, 8, 8]          36,864
#       BatchNorm2d-13             [-1, 64, 8, 8]             128
#              ReLU-14             [-1, 64, 8, 8]               0
#            Conv2d-15             [-1, 64, 8, 8]          36,864
#       BatchNorm2d-16             [-1, 64, 8, 8]             128
#              ReLU-17             [-1, 64, 8, 8]               0
#        BasicBlock-18             [-1, 64, 8, 8]               0
#            Conv2d-19            [-1, 128, 4, 4]          73,728
#       BatchNorm2d-20            [-1, 128, 4, 4]             256
#              ReLU-21            [-1, 128, 4, 4]               0
#            Conv2d-22            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-23            [-1, 128, 4, 4]             256
#            Conv2d-24            [-1, 128, 4, 4]           8,192
#       BatchNorm2d-25            [-1, 128, 4, 4]             256
#              ReLU-26            [-1, 128, 4, 4]               0
#        BasicBlock-27            [-1, 128, 4, 4]               0
#            Conv2d-28            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-29            [-1, 128, 4, 4]             256
#              ReLU-30            [-1, 128, 4, 4]               0
#            Conv2d-31            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-32            [-1, 128, 4, 4]             256
#              ReLU-33            [-1, 128, 4, 4]               0
#        BasicBlock-34            [-1, 128, 4, 4]               0
#            Conv2d-35            [-1, 256, 2, 2]         294,912
#       BatchNorm2d-36            [-1, 256, 2, 2]             512
#              ReLU-37            [-1, 256, 2, 2]               0
#            Conv2d-38            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-39            [-1, 256, 2, 2]             512
#            Conv2d-40            [-1, 256, 2, 2]          32,768
#       BatchNorm2d-41            [-1, 256, 2, 2]             512
#              ReLU-42            [-1, 256, 2, 2]               0
#        BasicBlock-43            [-1, 256, 2, 2]               0
#            Conv2d-44            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-45            [-1, 256, 2, 2]             512
#              ReLU-46            [-1, 256, 2, 2]               0
#            Conv2d-47            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-48            [-1, 256, 2, 2]             512
#              ReLU-49            [-1, 256, 2, 2]               0
#        BasicBlock-50            [-1, 256, 2, 2]               0
#            Conv2d-51            [-1, 512, 1, 1]       1,179,648
#       BatchNorm2d-52            [-1, 512, 1, 1]           1,024
#              ReLU-53            [-1, 512, 1, 1]               0
#            Conv2d-54            [-1, 512, 1, 1]       2,359,296
#       BatchNorm2d-55            [-1, 512, 1, 1]           1,024
#            Conv2d-56            [-1, 512, 1, 1]         131,072
#       BatchNorm2d-57            [-1, 512, 1, 1]           1,024
#              ReLU-58            [-1, 512, 1, 1]               0
#        BasicBlock-59            [-1, 512, 1, 1]               0
#            Conv2d-60            [-1, 512, 1, 1]       2,359,296
#       BatchNorm2d-61            [-1, 512, 1, 1]           1,024
#              ReLU-62            [-1, 512, 1, 1]               0
#            Conv2d-63            [-1, 512, 1, 1]       2,359,296
#       BatchNorm2d-64            [-1, 512, 1, 1]           1,024
#              ReLU-65            [-1, 512, 1, 1]               0
#        BasicBlock-66            [-1, 512, 1, 1]               0
# AdaptiveAvgPool2d-67            [-1, 512, 1, 1]               0
#            Linear-68                   [-1, 10]           5,130
# ================================================================
# Total params: 11,181,642
# Trainable params: 5,130
# Non-trainable params: 11,176,512
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 1.29
# Params size (MB): 42.65
# Estimated Total Size (MB): 43.95
# ----------------------------------------------------------------

# %%
BATCH_SIZE = 128
workers = 2
trainloader = data.DataLoader(trainset,
                              shuffle = True,
                              batch_size=BATCH_SIZE,
                              num_workers=workers)
testloader = data.DataLoader(testset,
                              batch_size=BATCH_SIZE,
                              num_workers=workers)

# %%
def train_step(model, optimizer, criterion, trainloader):
    model.train()
    total_loss = 0
    correct = 0
    total = 0
    
    for i, (img,label) in enumerate(trainloader):
        optimizer.zero_grad()
        
        img = Variable(img).view(-1,3,IMG_SIZE,IMG_SIZE).to(device)
        label = Variable(label).to(device)
        
        output = model(img)
        loss = criterion(output,label)
        total_loss += loss.data
        loss.backward()
        optimizer.step()
        
        predictions = torch.max(output, 1)[1]
        correct += (predictions==label).sum()
        total += len(label)
        
    accuracy = correct*1.0/total
    return total_loss, accuracy

# %%
def evaluate_step(model, criterion, testloader):
    model.eval()
    total_loss = 0
    correct = 0
    total = 0
    
    with torch.no_grad():
        for i, (img,label) in enumerate(testloader):
            
            img = Variable(img).view(-1,3,IMG_SIZE,IMG_SIZE).to(device)
            label = Variable(label).to(device)
            
            output = model(img)
            loss = criterion(output,label)

            total_loss += loss.data
            predictions = torch.max(output, 1)[1]
            correct += (predictions==label).sum()
            total += len(label)
        accuracy = correct*1.0/total
    return total_loss, accuracy

# %%
TRAIN_DATA = 1

loss_list = {
    "train": [],
    "val": []
}

acc_list = {
    "train": [],
    "val": []
}


if TRAIN_DATA:
    EPOCHS = 100
    print("Start training...")
    for epoch in range(EPOCHS):
        train_loss, train_acc = train_step(model, optimizer, criterion,trainloader)
        val_loss, val_acc = evaluate_step(model, criterion,testloader)
        loss_list["train"].append(train_loss)
        loss_list["val"].append(val_loss)
        acc_list["train"].append(train_acc)
        acc_list["val"].append(val_acc)
        print(f"Epoch: [{epoch+1}|{EPOCHS}] \n\t Training Loss: {train_loss:.3f} | Training Acc: {train_acc:.3f}\n\t Validating Loss: {val_loss:.3f} | Validating Acc: {val_acc:.3f}")
        torch.save(model.state_dict(), "model/modelVGG19.pt")
    print("Training Completed!")
# Out:
# Start training...
# Epoch: [1|100]
# 	 Training Loss: 816.098 | Training Acc: 0.259
# 	 Validating Loss: 147.599 | Validating Acc: 0.345
# Epoch: [2|100]
# 	 Training Loss: 704.841 | Training Acc: 0.373
# 	 Validating Loss: 139.284 | Validating Acc: 0.385
# Epoch: [3|100]
# 	 Training Loss: 679.885 | Training Acc: 0.395
# 	 Validating Loss: 135.324 | Validating Acc: 0.403
# Epoch: [4|100]
# 	 Training Loss: 666.220 | Training Acc: 0.408
# 	 Validating Loss: 133.600 | Validating Acc: 0.417
# Epoch: [5|100]
# 	 Training Loss: 656.603 | Training Acc: 0.416
# 	 Validating Loss: 132.730 | Validating Acc: 0.422
# Epoch: [6|100]
# 	 Training Loss: 650.166 | Training Acc: 0.423
# 	 Validating Loss: 131.521 | Validating Acc: 0.424
# Epoch: [7|100]
# 	 Training Loss: 646.030 | Training Acc: 0.427
# 	 Validating Loss: 130.878 | Validating Acc: 0.425
# Epoch: [8|100]
# 	 Training Loss: 643.446 | Training Acc: 0.425
# 	 Validating Loss: 130.634 | Validating Acc: 0.428
# Epoch: [9|100]
# 	 Training Loss: 640.381 | Training Acc: 0.431
# 	 Validating Loss: 127.540 | Validating Acc: 0.442
# Epoch: [53|100]
# 	 Training Loss: 626.406 | Training Acc: 0.442
# 	 Validating Loss: 127.535 | Validating Acc: 0.439
# Epoch: [54|100]
# 	 Training Loss: 626.980 | Training Acc: 0.443
# 	 Validating Loss: 127.200 | Validating Acc: 0.443
# Epoch: [55|100]
# 	 Training Loss: 627.156 | Training Acc: 0.444
# 	 Validating Loss: 127.756 | Validating Acc: 0.439
# Epoch: [56|100]
# 	 Training Loss: 623.837 | Training Acc: 0.444
# 	 Validating Loss: 127.888 | Validating Acc: 0.441
# Epoch: [57|100]
# 	 Training Loss: 626.891 | Training Acc: 0.443
# 	 Validating Loss: 127.475 | Validating Acc: 0.440
# Epoch: [58|100]
# 	 Training Loss: 626.235 | Training Acc: 0.444
# 	 Validating Loss: 126.905 | Validating Acc: 0.442
# Epoch: [59|100]
# 	 Training Loss: 624.833 | Training Acc: 0.443
# 	 Validating Loss: 127.459 | Validating Acc: 0.440
# Epoch: [60|100]
# 	 Training Loss: 627.461 | Training Acc: 0.444
# 	 Validating Loss: 127.502 | Validating Acc: 0.442
# Epoch: [61|100]
# 	 Training Loss: 627.500 | Training Acc: 0.441
# 	 Validating Loss: 127.037 | Validating Acc: 0.439
# Epoch: [62|100]
# 	 Training Loss: 625.265 | Training Acc: 0.443
# 	 Validating Loss: 127.331 | Validating Acc: 0.441
# Epoch: [63|100]
# 	 Training Loss: 624.329 | Training Acc: 0.445
# 	 Validating Loss: 127.561 | Validating Acc: 0.437
# Epoch: [64|100]
# 	 Training Loss: 622.342 | Training Acc: 0.447
# 	 Validating Loss: 127.632 | Validating Acc: 0.437
# Epoch: [65|100]
# 	 Training Loss: 625.208 | Training Acc: 0.444
# 	 Validating Loss: 127.721 | Validating Acc: 0.438
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-3f542b8d82bf> in <module>
#      16     print("Start training...")
#      17     for epoch in range(EPOCHS):
# ---> 18         train_loss, train_acc = train_step(model, optimizer, criterion,trainloader)
#      19         val_loss, val_acc = evaluate_step(model, criterion,testloader)
#      20         loss_list["train"].append(train_loss)
#
# <ipython-input-16-da971f56a5a7> in train_step(model, optimizer, criterion, trainloader)
#       8         optimizer.zero_grad()
#       9
# ---> 10         img = Variable(img).view(-1,3,IMG_SIZE,IMG_SIZE).to(device)
#      11         label = Variable(label).to(device)
#      12
#
# KeyboardInterrupt:

# %%
def plot(loss_list, acc_list, EPOCHS):
    fig = plt.figure(figsize=(20,5))
    fig.add_subplot(121)
    plt.plot(range(EPOCHS), loss_list["train"], label = "Training Loss")
    plt.plot(range(EPOCHS), loss_list["val"], label = "Validating Loss", color="orange")
    plt.title("Loss per epoch")
    
    fig.add_subplot(122)
    plt.plot(range(EPOCHS), acc_list["train"], label = "Training Accuracy")
    plt.plot(range(EPOCHS), acc_list["val"], label = "Validating Accuracy", color="orange")
    plt.title("Accuracy per epoch")
    plt.show()

plot(loss_list, acc_list, EPOCHS)
