# %%
import torch
import torch.utils.data as data
from torchvision import datasets, transforms
import numpy as np 
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw 
import cv2
import csv
import os
from classes import CNN

# %%
device = torch.device("cuda: 0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
TRAIN_DIR = "data/train"
TRAIN_LABEL = "data/train.csv"

# %%
annotation = np.load(os.path.join(TRAIN_DIR,"annotation.npy"),allow_pickle=True)

# %%
a = np.random.randint(30000)
fig = plt.figure(figsize=(20,30))
for id, (name,label,bbox) in enumerate(annotation[a:a+10]):
    fig.add_subplot(5,2,id+1)
    shape = [bbox[0],bbox[1],bbox[0]+bbox[2],bbox[1]+bbox[3]]
    img = cv2.imread(os.path.join(TRAIN_DIR,name))
    cv2.rectangle(img,(bbox[0],bbox[1]),(bbox[0]+bbox[2],bbox[1]+bbox[3]),color = (255,0,0),thickness = 1)
    plt.imshow(img)
plt.show()

# %%
a = np.random.randint(30000)
name,label,bbox = annotation[a]
fig = plt.figure(figsize=(10,10))
img = cv2.imread(os.path.join(TRAIN_DIR,name))
x,y,w,h = bbox
img_bbox = img[y:y+h,x:x+w]
#img_bbox = cv2.resize(img_bbox,(28,28))
#img_bbox_gray = cv2.cvtColor(img_bbox,cv2.COLOR_BGR2GRAY)
#cv2.rectangle(img,(bx,y),(bx+br,y+h),(255,0,0),2)
bbox_digits = []
for i in range(len(label)):
    br = int(w/len(label))
    bx = x+br*i
    by = y
    bw = br
    bh = h
    if bx<x+w:
        bbox_temp = img[by:by+bh,bx:bx+bw]
        bbox_temp = cv2.resize(bbox_temp,(64,64))
        bbox_digits.append(bbox_temp)
        #cv2.rectangle(img,(bx,by),(bx+bw,by+bh),(255,0,0),1)
        
plt.subplot(2,3,1)
plt.imshow(img)
for id, i in enumerate(bbox_digits):
    plt.subplot(2,3,id+2)
    plt.imshow(i)
plt.show()
